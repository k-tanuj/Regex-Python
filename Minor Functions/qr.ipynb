# %%
# !pip install qrcode
# Out:
# ...
#   Using cached qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# ...
# Using cached qrcode-8.2-py3-none-any.whl (45 kB)
# ...

# %%
import qrcode

# %%
data = "https://www.linkedin.com/in/tanuj-kumawat-34b461318/"
tanuj = "https://www.tanujk.com"

# %%
qr = qrcode.make(data)
qr.save("linkedin.png")
print("1st QR IS 'linkiedin.png'")
# Out:
# 1st QR IS 'linkiedin.png'

# %%
qr2 = qrcode.make(tanuj)
qr2.save("tanuj.png")
print("2nd QR IS 'tanuj.png'")
# Out:
# 2nd QR IS 'tanuj.png'
